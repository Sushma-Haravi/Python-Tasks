# %%
import matplotlib.pyplot as plt
from tabulate import tabulate
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mat

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/Users/SUSHMA/Downloads/DS1_C5_S3_BazilHousing_Data_Hackathon.csv')
df
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 0           São Paulo    70      2         1               1      7
# 1           São Paulo   320      4         4               0     20
# 2        Porto Alegre    80      1         1               1      6
# 3        Porto Alegre    51      2         1               0      2
# 4           São Paulo    25      1         1               0      1
# ...               ...   ...    ...       ...             ...    ...
# 10687    Porto Alegre    63      2         1               1      5
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 0          acept      furnished      2065              3300
# ...

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=df['city'])
plt.show()

# %%
df.shape
# Out:
# (10692, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 10692 non-null  object
#  1   area                 10692 non-null  int64
#  2   rooms                10692 non-null  int64
#  3   bathroom             10692 non-null  int64
#  4   parking spaces       10692 non-null  int64
#  5   floor                10692 non-null  int64
#  6   animal               10692 non-null  object
#  7   furniture            10692 non-null  object
#  8   hoa (R$)             10692 non-null  int64
#  9   rent amount (R$)     10692 non-null  int64
#  10  property tax (R$)    10692 non-null  int64
#  11  fire insurance (R$)  10692 non-null  int64
#  12  total (R$)           10692 non-null  int64
# dtypes: int64(10), object(3)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0     São Paulo    70      2         1               1      7      acept
# 1     São Paulo   320      4         4               0     20      acept
# 2  Porto Alegre    80      1         1               1      6      acept
# 3  Porto Alegre    51      2         1               0      2      acept
# 4     São Paulo    25      1         1               0      1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# ...

# %%
df.tail()
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 10687    Porto Alegre    63      2         1               1      5
# 10688       São Paulo   285      4         4               4     17
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 10687  not acept      furnished       402              1478
# 10688      acept  not furnished      3100             15000
# 10689  not acept      furnished       980              6000
# 10690      acept      furnished      1585             12000
# 10691      acept  not furnished         0              1400
#
#        property tax (R$)  fire insurance (R$)  total (R$)
# 10687                 24                   22        1926
# 10688                973                  191       19260
# ...

# %%
df.isnull().sum()
# Out:
# city                   0
# area                   0
# rooms                  0
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['city', 'area', 'rooms', 'bathroom', 'parking spaces', 'floor',
#        'animal', 'furniture', 'hoa (R$)', 'rent amount (R$)',
#        'property tax (R$)', 'fire insurance (R$)', 'total (R$)'],
#       dtype='object')

# %%
def sep_datatypes(df):
    cat=list(df.select_dtypes(include='object').columns)
    num=list(df.select_dtypes(exclude='object').columns)
    print(tabulate({"categorical":cat,"numerical":num},headers='keys'))
sep_datatypes(df)
# Out:
# categorical    numerical
# -------------  -------------------
# city           area
# animal         rooms
# furniture      bathroom
#                parking spaces
#                floor
#                hoa (R$)
#                rent amount (R$)
#                property tax (R$)
#                fire insurance (R$)
#                total (R$)

# %%
def info_of_cat(col):
    print(f" unique values in {col} are : {df[col].unique()}")
    print(f" mode of {col} is : {df[col].mode()[0]}")
    print(f" number of missing values in {col} is : {df[col].isnull().sum()}")

# %%
def info_of_num(col):
    print(f" mean of the {col} is : {df[col].mean()}")
    print(f" median of the {col} is : {df[col].median()}")
    print(f" mode of the {col} is : {df[col].mode()[0]}")
    print(f" standard deviation of {col} is : {df[col].std()}")
    print(f" number of missing values in {col} is : {df[col].isnull().sum()}")

# %% [markdown]
# ## Bivariate and multivariate analysis of categorical columns for bachelors

# %%
df1=df[(df['city']!='Rio de Janeiro')&(df['city']!='São Paulo')]
df1
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 2        Porto Alegre    80      1         1               1      6
# 3        Porto Alegre    51      2         1               0      2
# 11           Campinas    46      1         1               1     10
# 15           Campinas   330      4         6               6      0
# 21     Belo Horizonte    42      1         1               1     17
# ...               ...   ...    ...       ...             ...    ...
# 10667  Belo Horizonte    75      2         1               1      3
# 10673    Porto Alegre   220      3         2               2     15
# 10676    Porto Alegre    40      1         1               0      1
# 10682    Porto Alegre   160      3         2               3      4
# 10687    Porto Alegre    63      2         1               1      5
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 2          acept  not furnished      1000              2800
# ...

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of animals')
percentage=df1['animal'].value_counts()
print(percentage)
label=list(df1['animal'].value_counts().index)

sns.countplot(x=df1['animal'],ax=ax[0])
plt.pie(percentage,labels=label,autopct='%0.2f%%')
plt.show()
# Out:
# acept        2629
# not acept     675
# Name: animal, dtype: int64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of furniture')
percentage=df1['furniture'].value_counts()
print(percentage)
label=list(df1['furniture'].value_counts().index)

sns.countplot(x=df1['furniture'],ax=ax[0])
plt.pie(percentage,labels=label,autopct='%0.2f%%')
plt.show()
# Out:
# not furnished    2697
# furnished         607
# Name: furniture, dtype: int64

# %%
task1=df1.groupby(by=df1['city'])[['property tax (R$)']].mean()
task2=df1.groupby(by=df1['city'])[['area']].mean()
task3=df1.groupby(by=df1['city'])[['total (R$)']].mean()

# %%
fig,ax=plt.subplots(1,3,figsize=(12,15))
t1=task1['property tax (R$)']
ax[0].set_title('property tax (R$)')
label=task1.index
ax[0].pie(x=t1,labels=label,autopct='%0.2f%%')

t2=task2['area']
ax[1].set_title('area')
label=task2.index
ax[1].pie(x=t2,labels=label,autopct='%0.2f%%')

t3=task3['total (R$)']
ax[2].set_title('total (R$)')
label=task3.index
ax[2].pie(x=t3,labels=label,autopct='%0.2f%%')
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of city')
percentage=df1['city'].value_counts()
print(percentage)
label=list(df1['city'].value_counts().index)

sns.countplot(x=df1['city'],ax=ax[0])
plt.pie(percentage,labels=label,autopct='%0.2f%%')
plt.show()
# Out:
# Belo Horizonte    1258
# Porto Alegre      1193
# Campinas           853
# Name: city, dtype: int64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of city')
percentage=df1['city'].value_counts()
print(percentage)
label=list(df1['city'].value_counts().index)

sns.countplot(x=df1['city'],ax=ax[0])
plt.pie(percentage,labels=label,autopct='%0.2f%%')
plt.show()

# %%
bcat=df1[(df1['animal']=='not acept')&(df1['rooms']==1)&(df1['bathroom']==1)&(df1['floor']==1)]
bcat
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 76       Porto Alegre    47      1         1               1      1
# 162          Campinas    24      1         1               0      1
# 244      Porto Alegre    47      1         1               1      1
# 1278     Porto Alegre    49      1         1               0      1
# 1387     Porto Alegre    47      1         1               1      1
# ...               ...   ...    ...       ...             ...    ...
# 10218  Belo Horizonte    25      1         1               1      1
# 10306    Porto Alegre    47      1         1               1      1
# 10404  Belo Horizonte    24      1         1               0      1
# 10431    Porto Alegre    47      1         1               1      1
# 10623    Porto Alegre    47      1         1               1      1
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 76     not acept      furnished       400              2200
# ...

# %%
bcat.shape
# Out:
# (675, 13)

# %%
info_of_cat('hoa (R$)')
# Out:
#  unique values in hoa (R$) are : [2065 1200 1000 ... 1462 2515 3519]
#  mode of hoa (R$) is : 0
#  number of missing values in hoa (R$) is : 0

# %%
info_of_cat('rent amount (R$)')
# Out:
#  unique values in rent amount (R$) are : [ 3300  4960  2800 ... 10140  7521  1478]
#  mode of rent amount (R$) is : 2500
#  number of missing values in rent amount (R$) is : 0

# %%
info_of_cat('property tax (R$)')
# Out:
#  unique values in property tax (R$) are : [ 211 1750    0 ... 1370  602 1287]
#  mode of property tax (R$) is : 0
#  number of missing values in property tax (R$) is : 0

# %%
info_of_cat('fire insurance (R$)')
# Out:
#  unique values in fire insurance (R$) are : [ 42  63  41  17  11 121  25 191  30  27   8  54  56  39  16 181  58  36
#   14  24  45  20  48  23  22  33  51  26  21  18  44 153  53  34  12  82
#   49  50  52  19 115  91  70  61  66  28  77  64  71 125  13 108 160 222
#   38   7  46  37 211  84  32 127  94  99  83  31 226 102  89 196 254  29
#   43 136  15 158  55  73  65 110 133  68  10  92  74 100  60 155 137  76
#  165  59 149  80 151  78 163 107 192 140  67  96  35 229  86 134  57 200
#   97 106 122   9  85  47 188  40  62 193 154 116 126 146 156 130 117  87
#  132 170 123  88  75 174  90 157 113 246 139 104 105 177 178 173 194  98
#  120 220 210 214 109 148 128  72 162 159 166 142  79 129 111   5 164 103
#  131 224  69 101 141  81   6 267 138 180 189 145 114 135 118 677 175 112
#  238 338 152 305 187  93 144 230 143 119 197 198 203  95 147 199 167 168
#  185 161 172 184 124 182 301 221 248   4 183 205 376 249 451   3 179 171]
#  mode of fire insurance (R$) is : 16
# ...

# %%
info_of_cat('total (R$)')
# Out:
#  unique values in total (R$) are : [ 5618  7973  3841 ...  3395  4695 19260]
#  mode of total (R$) is : 2555
#  number of missing values in total (R$) is : 0

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=df1['city'],hue=df1['animal'])
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of furniture')
percentage=bcat['furniture'].value_counts()
print(percentage)
label=list(bcat['furniture'].value_counts().index)

sns.countplot(x=bcat['furniture'],ax=ax[0])
plt.pie(percentage,labels=label,autopct='%0.2f%%')
plt.show()
# Out:
# furnished        39
# not furnished    25
# Name: furniture, dtype: int64

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of city')
percentage=bcat['city'].value_counts()
print(percentage)
label=list(bcat['city'].value_counts().index)

sns.countplot(x=bcat['city'],ax=ax[0])
plt.pie(percentage,labels=label,autopct='%0.2f%%')
plt.show()
# Out:
# Porto Alegre      31
# Belo Horizonte    22
# Campinas          11
# Name: city, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=bcat['city'],hue=bcat['furniture'])
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.countplot(x=bcat['city'],hue=bcat['furniture'],ax=ax[0])
sns.countplot(x=bcat['city'],hue=bcat['animal'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation : belo horizontal city have most family to not to accept the animal. and not furnished.

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.histplot(hue=bcat.city,x=bcat['total (R$)'],ax=ax[0])
sns.boxplot(y=bcat.city,x=bcat['total (R$)'],ax=ax[1])
plt.show()

# %%
mean=int(df1['rent amount (R$)'].mean())
mean

x= df1[df1['rent amount (R$)']>5000].index
x
# Out:
# Int64Index([   15,    37,    57,    65,    91,    93,   107,   114,   143,
#               200,
#             ...
#             10507, 10530, 10532, 10563, 10567, 10590, 10599, 10611, 10645,
#             10656],
#            dtype='int64', length=453)

# %%
for index in x:
    df1.loc[index,'rent amount (R$)']=mean

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.histplot(hue=df1.city,x=df1['rent amount (R$)'],ax=ax[0])
sns.boxplot(y=df1.city,x=df1['rent amount (R$)'],ax=ax[1])
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.histplot(hue=df1.city,x=df1['property tax (R$)'],ax=ax[0])
sns.boxplot(y=df1.city,x=df1['property tax (R$)'],ax=ax[1])
plt.show()

# %%
mean=int(df1['property tax (R$)'].mean())
mean

x= df1[df1['property tax (R$)']>250].index
x
# Out:
# Int64Index([   15,    48,    77,    85,   319,   450,   455,   515,   537,
#               542,
#             ...
#              9927,  9989, 10031, 10224, 10323, 10325, 10352, 10365, 10487,
#             10656],
#            dtype='int64', length=191)

# %%
for index in x:
    df1.loc[index,'property tax (R$)']=mean

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.histplot(hue=df1.city,x=df1['property tax (R$)'],ax=ax[0])
sns.boxplot(y=df1.city,x=df1['property tax (R$)'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation : According to the categorical columns rental amount of campinas is low. so campian  city is better to choose for the bachelors.

# %% [markdown]
# # Bivariate and multivariate analysis of Numerical columns for bachelors

# %%
bnum=df1[(df1['rooms']<=2)&(df1['bathroom']==1)&(df1['parking spaces']==1)&(df1['floor']==1)]
bnum
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 76       Porto Alegre    47      1         1               1      1
# 100      Porto Alegre    50      1         1               1      1
# 137    Belo Horizonte   100      2         1               1      1
# 145    Belo Horizonte    50      2         1               1      1
# 186          Campinas    70      2         1               1      1
# ...               ...   ...    ...       ...             ...    ...
# 10306    Porto Alegre    47      1         1               1      1
# 10329        Campinas    50      1         1               1      1
# 10431    Porto Alegre    47      1         1               1      1
# 10623    Porto Alegre    47      1         1               1      1
# 10644  Belo Horizonte    65      2         1               1      1
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 76     not acept      furnished       400              2200
# ...

# %%
bnum.shape
# Out:
# (127, 13)

# %%
info_of_num('hoa (R$)')
# Out:
#  mean of the hoa (R$) is : 1174.0216984661429
#  median of the hoa (R$) is : 560.0
#  mode of the hoa (R$) is : 0
#  standard deviation of hoa (R$) is : 15592.305248403356
#  number of missing values in hoa (R$) is : 0

# %%
info_of_num('rent amount (R$)')
# Out:
#  mean of the rent amount (R$) is : 3896.247194163861
#  median of the rent amount (R$) is : 2661.0
#  mode of the rent amount (R$) is : 2500
#  standard deviation of rent amount (R$) is : 3408.5455176710816
#  number of missing values in rent amount (R$) is : 0

# %%
info_of_num('property tax (R$)')
# Out:
#  mean of the property tax (R$) is : 366.70435839880287
#  median of the property tax (R$) is : 125.0
#  mode of the property tax (R$) is : 0
#  standard deviation of property tax (R$) is : 3107.832321161917
#  number of missing values in property tax (R$) is : 0

# %%
info_of_num('fire insurance (R$)')
# Out:
#  mean of the fire insurance (R$) is : 53.300879161990274
#  median of the fire insurance (R$) is : 36.0
#  mode of the fire insurance (R$) is : 16
#  standard deviation of fire insurance (R$) is : 47.768030930197206
#  number of missing values in fire insurance (R$) is : 0

# %%
info_of_num('total (R$)')
# Out:
#  mean of the total (R$) is : 5490.4869996258885
#  median of the total (R$) is : 3581.5
#  mode of the total (R$) is : 2555
#  standard deviation of total (R$) is : 16484.72591235027
#  number of missing values in total (R$) is : 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.countplot(x=bnum['city'],hue=bnum['rooms'],ax=ax[0])
sns.countplot(x=bnum['city'],hue=bnum['bathroom'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation : According to numerical column for bacholer in the city of porto alegre has the highest number of less than 3 rooms and 1 bathroom system.

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.histplot(hue=bnum.city,x=bnum['rooms'],ax=ax[0])
sns.boxplot(y=bnum.city,x=bnum['rooms'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation : According to numerical columns Porto alegre city has the highest rental amount and belo campinas city has the lowest rental amount city. So for bachelors Belo Horizontal city is better than other two cities.

# %% [markdown]
# # Bivariate and multivariate analysis of categorical columns for mid-size family

# %%
mcat=df1[(df1['animal']=='acept')]
mcat
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor animal  \
# 2        Porto Alegre    80      1         1               1      6  acept
# 3        Porto Alegre    51      2         1               0      2  acept
# 11           Campinas    46      1         1               1     10  acept
# 15           Campinas   330      4         6               6      0  acept
# 27     Belo Horizonte    64      2         2               1     11  acept
# ...               ...   ...    ...       ...             ...    ...    ...
# 10659        Campinas   150      3         2               4      0  acept
# 10661        Campinas   250      1         2               2      0  acept
# 10673    Porto Alegre   220      3         2               2     15  acept
# 10676    Porto Alegre    40      1         1               0      1  acept
# 10682    Porto Alegre   160      3         2               3      4  acept
#
# ...

# %%
mcat.shape
# Out:
# (2629, 13)

# %%
info_of_cat('hoa (R$)')
# Out:
#  unique values in hoa (R$) are : [2065 1200 1000 ... 1462 2515 3519]
#  mode of hoa (R$) is : 0
#  number of missing values in hoa (R$) is : 0

# %%
info_of_cat('rent amount (R$)')
# Out:
#  unique values in rent amount (R$) are : [ 3300  4960  2800 ... 10140  7521  1478]
#  mode of rent amount (R$) is : 2500
#  number of missing values in rent amount (R$) is : 0

# %%
info_of_cat('property tax (R$)')
# Out:
#  unique values in property tax (R$) are : [ 211 1750    0 ... 1370  602 1287]
#  mode of property tax (R$) is : 0
#  number of missing values in property tax (R$) is : 0

# %%
info_of_cat('fire insurance (R$)')
# Out:
#  unique values in fire insurance (R$) are : [ 42  63  41  17  11 121  25 191  30  27   8  54  56  39  16 181  58  36
#   14  24  45  20  48  23  22  33  51  26  21  18  44 153  53  34  12  82
#   49  50  52  19 115  91  70  61  66  28  77  64  71 125  13 108 160 222
#   38   7  46  37 211  84  32 127  94  99  83  31 226 102  89 196 254  29
#   43 136  15 158  55  73  65 110 133  68  10  92  74 100  60 155 137  76
#  165  59 149  80 151  78 163 107 192 140  67  96  35 229  86 134  57 200
#   97 106 122   9  85  47 188  40  62 193 154 116 126 146 156 130 117  87
#  132 170 123  88  75 174  90 157 113 246 139 104 105 177 178 173 194  98
#  120 220 210 214 109 148 128  72 162 159 166 142  79 129 111   5 164 103
#  131 224  69 101 141  81   6 267 138 180 189 145 114 135 118 677 175 112
#  238 338 152 305 187  93 144 230 143 119 197 198 203  95 147 199 167 168
#  185 161 172 184 124 182 301 221 248   4 183 205 376 249 451   3 179 171]
#  mode of fire insurance (R$) is : 16
# ...

# %%
info_of_cat('total (R$)')
# Out:
#  unique values in total (R$) are : [ 5618  7973  3841 ...  3395  4695 19260]
#  mode of total (R$) is : 2555
#  number of missing values in total (R$) is : 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.countplot(x=mcat['city'],hue=mcat['animal'],ax=ax[0])
sns.countplot(x=mcat['city'],hue=mcat['furniture'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation :  According to mid-sized categorical column campian city has the lowest animal acceptance and not furnished.

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.kdeplot(hue=mcat.city,x=mcat['rent amount (R$)'],ax=ax[0])
sns.boxplot(y=mcat.city,x=mcat['rent amount (R$)'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation : According to the categorical column of mid size family porto alegre city has the lowest rental amount as compared to other two cities. so for porto alegre city is better to choose for mid size families.

# %% [markdown]
# # Bivariate and multivariate analysis of Numerical columns for mid-sized families

# %%
mnum=df1[(df1['rooms']>=2)&(df1['rooms']<5)&(df1['bathroom']<=3)&(df1['parking spaces']>=2)&(df1['parking spaces']<4)&(df1['floor']<=3)&(df1['rent amount (R$)']<=6000)]
mnum
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 48           Campinas   250      3         3               2      1
# 70     Belo Horizonte   220      4         2               3      3
# 105    Belo Horizonte   400      4         2               2      0
# 122    Belo Horizonte   100      3         2               2      2
# 146          Campinas   200      3         3               2      0
# ...               ...   ...    ...       ...             ...    ...
# 10578  Belo Horizonte    93      3         3               2      1
# 10582    Porto Alegre   140      3         2               2      0
# 10601  Belo Horizonte   160      3         2               2      0
# 10629        Campinas    83      2         2               2      1
# 10635    Porto Alegre   100      3         2               2      2
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 48         acept  not furnished      2200              1700
# ...

# %%
mnum.shape
# Out:
# (75, 13)

# %%
info_of_num('hoa (R$)')
# Out:
#  mean of the hoa (R$) is : 1174.0216984661429
#  median of the hoa (R$) is : 560.0
#  mode of the hoa (R$) is : 0
#  standard deviation of hoa (R$) is : 15592.305248403356
#  number of missing values in hoa (R$) is : 0

# %%
info_of_num('rent amount (R$)')
# Out:
#  mean of the rent amount (R$) is : 3896.247194163861
#  median of the rent amount (R$) is : 2661.0
#  mode of the rent amount (R$) is : 2500
#  standard deviation of rent amount (R$) is : 3408.5455176710816
#  number of missing values in rent amount (R$) is : 0

# %%
info_of_num('property tax (R$)')
# Out:
#  mean of the property tax (R$) is : 366.70435839880287
#  median of the property tax (R$) is : 125.0
#  mode of the property tax (R$) is : 0
#  standard deviation of property tax (R$) is : 3107.832321161917
#  number of missing values in property tax (R$) is : 0

# %%
info_of_num('fire insurance (R$)')
# Out:
#  mean of the fire insurance (R$) is : 53.300879161990274
#  median of the fire insurance (R$) is : 36.0
#  mode of the fire insurance (R$) is : 16
#  standard deviation of fire insurance (R$) is : 47.768030930197206
#  number of missing values in fire insurance (R$) is : 0

# %%
info_of_num('total (R$)')
# Out:
#  mean of the total (R$) is : 5490.4869996258885
#  median of the total (R$) is : 3581.5
#  mode of the total (R$) is : 2555
#  standard deviation of total (R$) is : 16484.72591235027
#  number of missing values in total (R$) is : 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of city')
percentage=mnum['city'].value_counts()
print(percentage)
label=list(mnum['city'].value_counts().index)

sns.countplot(x=mnum['city'],ax=ax[0])
plt.pie(percentage,labels=label,autopct='%0.2f%%')
plt.show()
# Out:
# Belo Horizonte    182
# Porto Alegre       78
# Campinas           74
# Name: city, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=mnum['city'],hue=mnum['rooms'])
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=mnum['city'],hue=mnum['floor'])
plt.show()

# %% [markdown]
# ## Interpretation : According to the mid sized family numerical column Porto Belo Horizontal city has the highest parking space and rooms as per the condition.

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.kdeplot(hue=mnum.city,x=mnum['rent amount (R$)'],ax=ax[0])
sns.boxplot(y=mnum.city,x=mnum['rent amount (R$)'],ax=ax[1])
plt.show()

# %%
mean=int(df1['rent amount (R$)'].mean())
mean

x= df1[df1['rent amount (R$)']>2000].index
x
# Out:
# Int64Index([    2,    15,    21,    28,    37,    39,    42,    57,    65,
#                70,
#             ...
#             10628, 10629, 10635, 10645, 10651, 10656, 10659, 10661, 10673,
#             10682],
#            dtype='int64', length=1448)

# %%
for index in x:
    df1.loc[index,'rent amount (R$)']=mean

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.histplot(hue=mnum.city,x=mnum['rent amount (R$)'],ax=ax[0])
sns.boxplot(y=mnum.city,x=mnum['rent amount (R$)'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation : According to the numerical columns of mid-sized family campians city is the lowest rentak rate as campared to other cities. so better to choose to campian city for mid sized family.

# %% [markdown]
# # Bivariate and multivariate analysis of categorical columns for Large family

# %%
lcat=df1[(df1['parking spaces']>2)&(df1['furniture']=='furnished')&(df1['rooms']>2)&(df1['bathroom']>3)]
lcat
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 15           Campinas   330      4         6               6      0
# 91       Porto Alegre   350      4         4               4      0
# 241    Belo Horizonte   570      5         6               7      0
# 346    Belo Horizonte   204      4         4               4     22
# 490      Porto Alegre   360      3         4               3      5
# ...               ...   ...    ...       ...             ...    ...
# 9989         Campinas   295      7         6               4      0
# 10172  Belo Horizonte   260      4         4               6     10
# 10342  Belo Horizonte   300      4         4               4     17
# 10353        Campinas   437      3         6               6      0
# 10530  Belo Horizonte   230      3         4               4     17
#
#           animal  furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# ...

# %%
lcat.shape
# Out:
# (438, 13)

# %%
info_of_cat('hoa (R$)')
# Out:
#  unique values in hoa (R$) are : [2065 1200 1000 ... 1462 2515 3519]
#  mode of hoa (R$) is : 0
#  number of missing values in hoa (R$) is : 0

# %%
info_of_cat('rent amount (R$)')
# Out:
#  unique values in rent amount (R$) are : [ 3300  4960  2800 ... 10140  7521  1478]
#  mode of rent amount (R$) is : 2500
#  number of missing values in rent amount (R$) is : 0

# %%
info_of_cat('property tax (R$)')
# Out:
#  unique values in property tax (R$) are : [ 211 1750    0 ... 1370  602 1287]
#  mode of property tax (R$) is : 0
#  number of missing values in property tax (R$) is : 0

# %%
info_of_cat('fire insurance (R$)')
# Out:
#  unique values in fire insurance (R$) are : [ 42  63  41  17  11 121  25 191  30  27   8  54  56  39  16 181  58  36
#   14  24  45  20  48  23  22  33  51  26  21  18  44 153  53  34  12  82
#   49  50  52  19 115  91  70  61  66  28  77  64  71 125  13 108 160 222
#   38   7  46  37 211  84  32 127  94  99  83  31 226 102  89 196 254  29
#   43 136  15 158  55  73  65 110 133  68  10  92  74 100  60 155 137  76
#  165  59 149  80 151  78 163 107 192 140  67  96  35 229  86 134  57 200
#   97 106 122   9  85  47 188  40  62 193 154 116 126 146 156 130 117  87
#  132 170 123  88  75 174  90 157 113 246 139 104 105 177 178 173 194  98
#  120 220 210 214 109 148 128  72 162 159 166 142  79 129 111   5 164 103
#  131 224  69 101 141  81   6 267 138 180 189 145 114 135 118 677 175 112
#  238 338 152 305 187  93 144 230 143 119 197 198 203  95 147 199 167 168
#  185 161 172 184 124 182 301 221 248   4 183 205 376 249 451   3 179 171]
#  mode of fire insurance (R$) is : 16
# ...

# %%
info_of_cat('total (R$)')
# Out:
#  unique values in total (R$) are : [ 5618  7973  3841 ...  3395  4695 19260]
#  mode of total (R$) is : 2555
#  number of missing values in total (R$) is : 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.countplot(x=lcat['city'],hue=lcat['animal'],ax=ax[0])
sns.countplot(x=lcat['city'],hue=lcat['furniture'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation: In the above graph porto alegre has the highest count of animal acceptance and furnished.

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.kdeplot(hue=lcat.city,x=lcat['rent amount (R$)'],ax=ax[0])
sns.boxplot(y=lcat.city,x=lcat['rent amount (R$)'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation : According to categorical column of campinas has the lowest rental amount as compared to other cities. so better to choose campinas city.

# %% [markdown]
# # Bivariate and multivariate analysis of Numerical columns for large family

# %%
lnum=df1[(df1['rooms']>2)&(df1['furniture']=='furnished')&(df1['parking spaces']>2)&(df1['bathroom']>3)&(df1['rent amount (R$)']>2500)]
lnum
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24884\1414577622.py in <module>
# ----> 1 lnum=df1[(df1['rooms']>2)&(df1['furniture']=='furnished')&(df1['parking spaces']>2)&(df1['bathroom']>3)&(df1['rent amount (R$)']>2500)]
#       2 lnum
#
# NameError: name 'df1' is not defined

# %%
lnum.shape
# Out:
# (173, 13)

# %%
info_of_num('hoa (R$)')
# Out:
#  mean of the hoa (R$) is : 1174.0216984661429
#  median of the hoa (R$) is : 560.0
#  mode of the hoa (R$) is : 0
#  standard deviation of hoa (R$) is : 15592.305248403356
#  number of missing values in hoa (R$) is : 0

# %%
info_of_num('rent amount (R$)')
# Out:
#  mean of the rent amount (R$) is : 3896.247194163861
#  median of the rent amount (R$) is : 2661.0
#  mode of the rent amount (R$) is : 2500
#  standard deviation of rent amount (R$) is : 3408.5455176710816
#  number of missing values in rent amount (R$) is : 0

# %%
info_of_num('property tax (R$)')
# Out:
#  mean of the property tax (R$) is : 366.70435839880287
#  median of the property tax (R$) is : 125.0
#  mode of the property tax (R$) is : 0
#  standard deviation of property tax (R$) is : 3107.832321161917
#  number of missing values in property tax (R$) is : 0

# %%
info_of_num('fire insurance (R$)')
# Out:
#  mean of the fire insurance (R$) is : 53.300879161990274
#  median of the fire insurance (R$) is : 36.0
#  mode of the fire insurance (R$) is : 16
#  standard deviation of fire insurance (R$) is : 47.768030930197206
#  number of missing values in fire insurance (R$) is : 0

# %%
info_of_num('total (R$)')
# Out:
#  mean of the total (R$) is : 5490.4869996258885
#  median of the total (R$) is : 3581.5
#  mode of the total (R$) is : 2555
#  standard deviation of total (R$) is : 16484.72591235027
#  number of missing values in total (R$) is : 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of city')
percentage=lcat['city'].value_counts()
print(percentage)
label=list(lcat['city'].value_counts().index)

sns.countplot(x=lcat['city'],ax=ax[0])
plt.pie(percentage,labels=label,autopct='%0.2f%%')
plt.show()
# Out:
# Belo Horizonte    42
# Porto Alegre      15
# Campinas          12
# Name: city, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=lcat['city'],hue=lcat['rooms'])
plt.show()

# %% [markdown]
# ## Interpretation : In the above graph belo horizontal has the highest count of floors in between 2 to 4 and rooms between 3 to 5.

# %%
fig,ax=plt.subplots(1,2,figsize=(15,8))
sns.kdeplot(hue=lcat.city,x=lcat['rent amount (R$)'],ax=ax[0])
sns.boxplot(y=lcat.city,x=lcat['rent amount (R$)'],ax=ax[1])
plt.show()

# %% [markdown]
# ## Interpretation : According to numerical column campinas city has the lowest rental amount so large family can choose campians city.
